# %%
import ROOT
import argparse
import math
import hist as hs
import numpy as np
from hist import Hist
import random
import matplotlib.pyplot as plt
import uproot 
import hist

import mplhep as hep

file=uproot.open("tmp/output_mumu.root")
x = file.keys()
#print(x)
#file.keys()

# %%
### Charge histogram
ax = plt.axes()
ax.set_facecolor("floralwhite")
hep.histplot( hist_q)
plt.yscale("log")
plt.xlabel("Charge ")
plt.ylabel("Events")
plt.xlim(-2,2.1)
plt.title('FCC-ee Simulation, charge ')
hep.cms.text(text = "Simulation", exp = "FCCee")
hep.cms.lumitext(text = "100 $ab^{-1}$")
plt.savefig("initial_charge")

# %%
### MOMENTUM HIST0GRAM
ax = plt.axes()
ax.set_facecolor("floralwhite")
hist_p_rebin = hist_p[hs.rebin(20)]
hist_all_p_rebin = hist_all_p[hs.rebin(20)]
hep.histplot( hist_p_rebin)
hep.histplot(hist_all_p_rebin)
plt.xlabel("momentum")
plt.ylabel("Events")
#plt.xlim(-2,2)
plt.title(' momentum ')
hep.cms.lumitext(text = "100 $ab^{-1}$")
hep.cms.text(text = "Simulation", exp = "FCCee")
plt.savefig("momentum")

# %%
hist_theta = file['wzp6_ee_nunuH_Hmumu_ecm240/ellipse;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/leps_all_theta_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/ellipse;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_theta_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_theta_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_theta_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_theta_cut0;1'].to_hist() + file['wzp6_ee_mumuH_Hmumu_ecm240/leps_theta_cut0;1'].to_hist()

# %%
### THETA HIST0GRAM
ax = plt.axes()
ax.set_facecolor("floralwhite")
hep.histplot( hist_theta)
plt.xlabel("Theta (rad) ")
plt.ylabel("Events")
plt.xlim(0,3.1)
plt.title(' theta ')
hep.cms.text(text = "Simulation", exp = "FCCee")
hep.cms.lumitext(text = "100 $ab^{-1}$")
plt.savefig("theta")

# %%
hist_ellipse = file['wzp6_ee_nunuH_Hmumu_ecm240/ellipse;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/ellipse;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/ellipse;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/ellipse;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/ellipse;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/ellipse;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/ellipse;1'].to_hist() + file['wzp6_ee_mumuH_Hmumu_ecm240/ellipse;1'].to_hist()
plt.xlim(0,2)
hep.histplot( hist_ellipse)
plt.xlabel("ellipse ")
plt.ylabel("Events")
hep.cms.text(text = "Simulation", exp = "FCCee")
hep.cms.lumitext(text = "100 $ab^{-1}$")
# Out:
# <Axes: xlabel='ellipse ', ylabel='Events'>

# %%
hist1 = file['wzp6_ee_nunuH_Hmumu_ecm240/leps_phi_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/leps_phi_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/leps_phi_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_phi_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_phi_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_phi_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_phi_cut0;1'].to_hist() + file['wzp6_ee_mumuH_Hmumu_ecm240/leps_phi_cut0;1'].to_hist()

# %%
### PHI HISTOGRAM
ax = plt.axes()
ax.set_facecolor("floralwhite")
hep.histplot( hist1)

plt.xlabel("phi ")
plt.ylabel("Events")
#plt.xlim(0,4)
plt.title(' phi')
hep.cms.text(text = "Simulation", exp = "FCCee")
hep.cms.lumitext(text = "100 $ab^{-1}$")
plt.savefig("phi")

# %%
hist1 = file['wzp6_ee_nunuH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist() + file['wzp6_ee_mumuH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()
hist2 = file['wzp6_ee_nunuH_Hmumu_ecm240/leps_no_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/leps_no_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/leps_no_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_no_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_no_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_no_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_no_cut0;1'].to_hist() + file['wzp6_ee_mumuH_Hmumu_ecm240/leps_no_cut0;1'].to_hist()

# %%
### LEPTON NUMBERS HISTOGRAM
ax = plt.axes()
ax.set_facecolor("floralwhite")
hep.histplot( hist1)
#print(hist1)
plt.xlabel("Number of leptons ")
plt.ylabel("Events")
plt.xlim(0,6)
plt.title('FCC-ee Simulation, leptons')
hep.cms.lumitext(text = "100 $ab^{-1}$")
hep.cms.text(text = "Simulation", exp = "FCCee")
plt.savefig("initial_no_lep")
print(hist1[0], hist1[1], hist1[2],hist1[3], hist1[4], hist1[5], hist1[6])

# %%
### LEPTONS
ax = plt.axes()
ax.set_facecolor("floralwhite")
hep.histplot( hist2)

plt.xlabel("Number of leptons ")
plt.ylabel("Events")
plt.xlim(0,6)
plt.title('FCC-ee Simulation, leptons')
hep.cms.lumitext(text = "100 $ab^{-1}$")
plt.savefig("initial_no_lep")

# %%
hist_cut3 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()

# %%
#hist_cut2 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/zll_m_cut4;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/zll_m_cut4;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/zll_m_cut4;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/zll_m_cut4;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/zll_m_cut4;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/zll_m_cut4;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/zll_m_cut4;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/zll_m_cut4;1'].to_hist()

# %%
hist_ZH0 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()
hist_WW0 = file['p8_ee_WW_ecm240/cutFlow_cut0;1']
hist_ZZ0 = file['p8_ee_ZZ_ecm240/cutFlow_cut0;1']
hist_rec = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/hll_recoil_m;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/hll_recoil_m;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/hll_recoil_m;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()

# %%
hist_ZH1 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/cutFlow_cut1;1']
hist_ZZ1 = file['p8_ee_ZZ_ecm240/cutFlow_cut1;1']
hist_rec = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/hll_recoil_m;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/hll_recoil_m;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/hll_recoil_m;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[175], line 4
#       2 hist_WW1 = file['p8_ee_WW_ecm240/cutFlow_cut1;1']
#       3 hist_ZZ1 = file['p8_ee_ZZ_ecm240/cutFlow_cut1;1']
# ----> 4 hist_rec = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/hll_recoil_m;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/hll_recoil_m;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/hll_recoil_m;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/hll_recoil_m;1'].to_hist()
#
# File /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/uproot/reading.py:2091, in ReadOnlyDirectory.__getitem__(self, where)
#    2089     else:
# ...

# %%
hist_ZH = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()+file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+ file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()+ file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()+ file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() 
hist_ZZ = file['p8_ee_ZZ_ecm240/cutFlow_cut0;1'].to_hist() + file['p8_ee_ZZ_ecm240/cutFlow_cut1;1'].to_hist()+file['p8_ee_ZZ_ecm240/cutFlow_cut2;1'].to_hist() + file['p8_ee_ZZ_ecm240/cutFlow_cut3;1'].to_hist() + file['p8_ee_ZZ_ecm240/cutFlow_cut4;1'].to_hist()+file['p8_ee_ZZ_ecm240/cutFlow_cut5;1'].to_hist()+file['p8_ee_ZZ_ecm240/cutFlow_cut6;1'].to_hist()
hist_WW = file['p8_ee_WW_ecm240/cutFlow_cut1;1'].to_hist() + file['p8_ee_WW_ecm240/cutFlow_cut0;1'].to_hist()+file['p8_ee_WW_ecm240/cutFlow_cut2;1'].to_hist() + file['p8_ee_WW_ecm240/cutFlow_cut3;1'].to_hist() +file['p8_ee_WW_ecm240/cutFlow_cut4;1'].to_hist()+file['p8_ee_WW_ecm240/cutFlow_cut5;1'].to_hist()+file['p8_ee_WW_ecm240/cutFlow_cut6;1'].to_hist()
hey = [ hist_ZZ, hist_WW]

# %%
plt.figure(figsize=(12,6))
hep.histplot(hey, label = [ "ZZ", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',], edgecolor = ['black', 'black'], linewidth=[1,1], stack = True)
#hep.histplot(hist_WW, label="$W^{-}W^{+}$", histtype = 'fill', color='deeppink', edgecolor= 'black', linewidth = 1)
#hep.histplot(hist_ZZ, label="ZZ", histtype = 'fill', color = 'skyblue', edgecolor= 'black', linewidth = 1)
hep.histplot(hist_ZH*10, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange', edgecolor= 'black', linewidth = 1)
plt.xticks([0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.5], ["$All$ $events$", "$ \geq 1\mu^{\pm} $", "$ \geq 2\mu^{\pm}$", "$Opposite$ $charge$", "$ 34 < p_{\mu^{+}\mu^{-}} < 72 $ ", "$MissingEnergy < 111 $", " $ 2D CUT$", 'JUST QQ']) # "$102 < m_{\mu^{+}\mu^{-}}$ < 127 "])
plt.ylabel("$Events$", size=12)
plt.yscale("log")
plt.xlabel('')
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,7)
plt.legend(loc='upper right')

# %%
hist_WW1 = file['p8_ee_WW_ecm240/sum_q;1']
hep.histplot(hist_WW1, histtype = 'fill')
#plt.xlim(40,120)
plt.legend(loc='upper right')

# %%
hist_ZH = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/hmm_recoil_m_cut3;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/hmm_recoil_m_cut3;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/hmm_recoil_m_cut3;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/hmm_recoil_m_cut3;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/hmm_recoil_m_cut3;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/hmm_recoil_m_cut3;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/hmm_recoil_m_cut3;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/hmm_recoil_m_cut3;1'].to_hist()
hist_WW  = file['p8_ee_WW_ecm240/hmm_recoil_m_cut3;1'].to_hist()
hist_ZZ  = file['p8_ee_ZZ_ecm240/hmm_recoil_m_cut3;1'].to_hist()

# %%
plt.figure(figsize=(8,7))
hep.histplot([hist_WW, hist_ZZ], label = [ "$WW$", "$ZZ$"] , histtype = 'fill', color = [ 'deeppink', 'skyblue'], stack = True)
#hep.histplot(hist_WW, label="WW) - signal$", histtype = 'fill', color = 'deeppink')
#hep.histplot(hist_ZH, label="ZH($\mu^{+}\mu^{-}) - signal$", color = 'orange')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('$Recoil $ $mass$ $[GeV]$', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
plt.legend(loc='upper right', fontsize = 8)
plt.ylim(0,1000000)
plt.xlim(0,189)
plt.savefig("Recoil mass")
# Out:
# /tmp/ipykernel_2165690/2768279578.py:12: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,1000000)

# %%
hist_ZH = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/hll_p_cut4;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/hll_p_cut4;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/hll_p_cut4;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()
hist_WW  = file['p8_ee_WW_ecm240/hll_p_cut4;1'].to_hist()
hist_ZZ  = file['p8_ee_ZZ_ecm240/hll_p_cut4;1'].to_hist()

# %%
plt.figure(figsize=(8,7))
hep.histplot([hist_ZZ, hist_WW], label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_ZH*10, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('$Momentum$ $[GeV]$', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
plt.legend(loc='upper right', fontsize = 8)
plt.xticks([0, 20,34,40, 60, 72,80, 100])
plt.xlim(0,108)
plt.ylim(0, 100000)
plt.vlines(34, 0, 10000, color = 'black', linestyles='dashed')
plt.vlines(72, 0, 10000, color = 'black', linestyles='dashed')
# Out:
# /tmp/ipykernel_3045310/1863412375.py:13: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0, 100000)

# %%
max = 0
index = 0
for i in range(92):
    y_s = 0 
    y_b = 0
    for j in range(i,150):
        y_s = y_s + hist_cut3.to_numpy()[0][j]
        y_b = y_b + hist_recoil_bkg.to_numpy()[0][j]
    s = y_s/math.sqrt(y_s+y_b)
    if s > max:
        max = s
        index = i
print(max, index)
max = 0
index = 0
for i in range(149, 91, -1):
    y_s = 0 
    y_b = 0
    for j in range(i, 0, -1):
        y_s = y_s + hist_cut3.to_numpy()[0][j]
        y_b = y_b + hist_recoil_bkg.to_numpy()[0][j]
    s = y_s/math.sqrt(y_s+y_b)
    if s > max:
        max = s
        index = i
print(max, index)

# %%
#hist_WW1 = file['p8_ee_WW_ecm240/hmm_m_final;1'].to_hist()
hist_ZZ1 =  file['p8_ee_ZZ_ecm240/hmm_m_final;1'].to_hist()
hist_ZH1 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/hmm_m_final;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/hmm_m_final;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/hmm_m_final;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/hmm_m_final;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/hmm_m_final;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/hmm_m_final;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/hmm_m_final;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/hmm_m_final;1'].to_hist()
hist_WW2 =  file['p8_ee_WW_ecm240/hmm_m_final;1'].to_hist()
###rebin
hist_SR = hist_ZH1[hs.rebin(20)]
hist_ZR = hist_ZZ1[hs.rebin(20)]

# %%
hep.histplot(hist_ZH1, label = "Z($\mu^{+}\mu^{-}) - signal$", color = 'orange')
#hep.histplot([ hist_ZZ1, hist_WW2, hist_ZH1], label = [  "$ZZ$", "$W^{-}W^{+}$", "ZH($\mu^{+}\mu^{-}) - signal$",] ,  color = [ 'skyblue', 'deeppink', 'orange'], stack = True)
#"ZH($\mu^{+}\mu^{-}) - signal$", "$ZZ$",
plt.xlabel("$Invariant$ $mass$ $[GeV]$", size=14)
plt.ylabel("$Events$", size=14)
plt.yscale("log")
#plt.xlim(102,127)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 10$ $ab^{-1} $", fontsize = 14)
plt.legend(loc='center left')

# %%
hist_cut3 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()

# %%
hist_mom = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/hll_p_cut4;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/hll_p_cut4;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/hll_p_cut4;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/hll_p_cut4;1'].to_hist()
hist_mom_bkg = file['p8_ee_WW_ecm240/hll_p_cut4;1'].to_hist()+file['p8_ee_ZZ_ecm240/hll_p_cut4;1'].to_hist()

# %%
hep.histplot(hist_mom_bkg, histtype = 'fill')
hep.histplot(hist_mom, histtype = 'fill')
plt.yscale("log")
plt.xlim(0,100)
plt.legend(loc='upper right')
#print(max(hist_cut3.to_numpy()))

# %%
max = 0
index = 0
print(hist_mom.to_numpy()[0][33])
for i in range(52):
    y_s = 0 
    y_b = 0
    for j in range(i,99):
        y_s = y_s + hist_mom.to_numpy()[0][j]
        y_b = y_b + hist_mom_bkg.to_numpy()[0][j]
    s = y_s/math.sqrt(y_s+y_b)
    if s > max:
        max = s
        index = i
print(max, index)
max = 0
index = 0
for i in range(100, 52, -1):
    y_s = 0 
    y_b = 0
    for j in range(i, 0, -1):
        y_s = y_s + hist_mom.to_numpy()[0][j]
        y_b = y_b + hist_mom_nkg.to_numpy()[0][j]
    s = y_s/math.sqrt(y_s+y_b)
    print(i,y_s, y_b, s)
    if s > max:
        max = s
        index = i
print(max, index)

# %%
max = 0
index = 0
for i in range(126):
    y_s = 0 
    y_b = 0
    for j in range(i,150):
        y_s = y_s + hist_mom.to_numpy()[0][j]
        y_b = y_b + hist_recoil_bkg.to_numpy()[0][j]
    s = y_s/math.sqrt(y_s+y_b)
    if s > max:
        max = s
        index = i
print(max, index)
max = 0
index = 0
for i in range(149, 126, -1):
    y_s = 0 
    y_b = 0
    for j in range(i, 0, -1):
        y_s = y_s + hist_cut3.to_numpy()[0][j]
        y_b = y_b + hist_recoil_bkg.to_numpy()[0][j]
    s = y_s/math.sqrt(y_s+y_b)
    if s > max:
        max = s
        index = i
print(max, index)

# %%
hist_ZZ1 =  file['p8_ee_ZZ_ecm240/hmm_m_final2;1'].to_hist()
hist_ZH1 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/hmm_m_final2;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/hmm_m_final2;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/hmm_m_final2;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/hmm_m_final2;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/hmm_m_final2;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/hmm_m_final2;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/hmm_m_final2;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/hmm_m_final2;1'].to_hist()
hist_WW2 =  file['p8_ee_WW_ecm240/hmm_m_final2;1'].to_hist()

ZZ = file['p8_ee_ZZ_ecm240/cutFlow_cut0;1'].to_hist()
accZZ = sum(hist_ZZ1.to_numpy()[0])/sum(ZZ.to_numpy()[0])
WW = file['p8_ee_WW_ecm240/cutFlow_cut0;1'].to_hist()
accWW = sum(hist_WW2.to_numpy()[0])/sum(WW.to_numpy()[0])
ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()
accZH = sum(hist_ZH1.to_numpy()[0])/sum(ZH.to_numpy()[0])
print(accZZ, accWW, accZH)

file = uproot.recreate("combine/Hgaga.root")
file["sig"] = hist_ZH1
file["bkg"] = hist_WW2 + hist_ZZ1


significance = sum(hist_ZH1.to_numpy()[0]) / math.sqrt( sum(hist_ZH1.to_numpy()[0])+ sum(hist_WW2.to_numpy()[0])+sum(hist_ZH1.to_numpy()[0]))
print(significance)
# Out:
# 0.0025457000000000023 0.03681389999999999 0.7446221446504666
# 0.9047715689532269

# %%
hep.histplot([hist_ZH1, hist_ZZ1, hist_WW2], label = ['zh', 'zz', 'ww'], stack = True)
plt.xlabel("Invariant mass peaks", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.xlim(102,127)
plt.legend(loc='upper left')
plt.savefig('.3')
# Out:
# /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/mplhep/error_estimation.py:49: RuntimeWarning: divide by zero encountered in divide
#   counts = sumw / scale
# /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/mplhep/error_estimation.py:49: RuntimeWarning: invalid value encountered in divide
#   counts = sumw / scale
# /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/mplhep/error_estimation.py:49: RuntimeWarning: divide by zero encountered in divide
#   counts = sumw / scale
# /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/mplhep/error_estimation.py:49: RuntimeWarning: invalid value encountered in divide
#   counts = sumw / scale

# %%
hep.histplot([ hist_ZZ1, hist_WW2], label = [  "$ZZ$", "$W^{-}W^{+}$"] ,  color = [ 'skyblue', 'deeppink'] , histtype = 'fill', stack = True)
hep.histplot(hist_ZH1, label = "ZH($\mu^{+}\mu^{-}) - signal$", color = 'gold')

#"ZH($\mu^{+}\mu^{-}) - signal$", "$ZZ$",
plt.xlabel("$Invariant$ $mass$ $[GeV]$", size=14)
plt.ylabel("$Events$", size=14)
#plt.yscale("log")
plt.xlim(120,127)
plt.ylim(0,150)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
plt.legend(loc='upper left')

# %%
#hep.histplot(hist_ZH1, label = "ZH($\mu^{+}\mu^{-}) - signal$", color = 'orange')
print([ hist_ZZ1, hist_WW2, hist_ZH1 ])
hep.histplot([ hist_ZZ1, hist_WW2, hist_ZH1 ], label = [  "$ZZ$", "$W^{-}W^{+}$", "ZH($\mu^{+}\mu^{-}) - signal$" ] ,  color = [ 'skyblue', 'deeppink','orange'] , stack = True)
#"ZH($\mu^{+}\mu^{-}) - signal$", "$ZZ$",
plt.xlabel("$Invariant$ $mass$ $[GeV]$", size=14)
plt.ylabel("$Events$", size=14)
#plt.yscale("log")
plt.xlim(120,127)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
plt.legend(loc='upper left')

#plt.xlim(123,126)
#plt.ylim(1400,1600)

file = uproot.recreate("combine/Hmumu.root")
file["sig"] = hist_ZH1
file["bkg"] = hist_WW2 + hist_ZZ1
# Out:
# [Hist(Regular(3000, 0, 300, name='xaxis'), storage=Weight()) # Sum: WeightedSum(value=19778.8, variance=19353.1), Hist(Regular(3000, 0, 300, name='xaxis'), storage=Weight()) # Sum: WeightedSum(value=57213.6, variance=10624.7), Hist(Regular(3000, 0, 300, name='xaxis'), storage=Weight()) # Sum: WeightedSum(value=159.037, variance=0.0238831)]
# /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/mplhep/error_estimation.py:49: RuntimeWarning: divide by zero encountered in divide
#   counts = sumw / scale
# /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/mplhep/error_estimation.py:49: RuntimeWarning: divide by zero encountered in divide
#   counts = sumw / scale

# %%
hist_ZH =  file[ 'wzp6_ee_nunuH_Hmumu_ecm240/missingEnergy;1'].to_hist() #+
hist_me = file['wzp6_ee_eeH_Hmumu_ecm240/missingEnergy;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/missingEnergy;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/missingEnergy;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/missingEnergy;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/missingEnergy;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/missingEnergy;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/missingEnergy;1'].to_hist()
hist_WW = file['p8_ee_WW_ecm240/missingEnergy;1'].to_hist()
hist_ZZ = file['p8_ee_ZZ_ecm240/missingEnergy;1'].to_hist()
#file[ 'wzp6_ee_nunuH_Hmumu_ecm240/missingEnergy;1'].to_hist()
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 hist_ZH =  file[ 'wzp6_ee_nunuH_Hmumu_ecm240/missingEnergy;1'].to_hist() #+
#       2 hist_me = file['wzp6_ee_eeH_Hmumu_ecm240/missingEnergy;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/missingEnergy;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/missingEnergy;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/missingEnergy;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/missingEnergy;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/missingEnergy;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/missingEnergy;1'].to_hist()
#       3 hist_WW = file['p8_ee_WW_ecm240/missingEnergy;1'].to_hist()
#
# File /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/uproot/writing/writable.py:968, in WritableDirectory.__getitem__(self, where)
#     966 if self._file.sink.closed:
# ...

# %%
plt.figure(figsize=(10,10))
#hep.histplot([hist_ZZ, hist_WW], label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_me, label="$other$ $signal$", histtype = 'fill', color = 'blue')
hep.histplot(hist_ZH, label='Z(nunu)H($\mu^{+}\mu^{-}) - signal$', histtype = 'fill', color = 'orange')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('$Missing $ $Energy$ $[GeV]$', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
plt.legend(loc='upper right', fontsize = 8)
plt.xticks([0, 20,40,60, 80, 100, 111, 130])
plt.xlim(0,135)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 3
#       1 plt.figure(figsize=(10,10))
#       2 #hep.histplot([hist_ZZ, hist_WW], label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
# ----> 3 hep.histplot(hist_me, label="$other$ $signal$", histtype = 'fill', color = 'blue')
#       4 hep.histplot(hist_ZH, label='Z(nunu)H($\mu^{+}\mu^{-}) - signal$', histtype = 'fill', color = 'orange')
#       6 plt.ylabel("$Events$", size=14)
#
# NameError: name 'hist_me' is not defined

# %%
max = 0
index = 0
for i in range(149, 0, -1):
    y_s = 0 
    y_b = 0
    for j in range(i, 0, -1):
        y_s = y_s + hist_ZH1.to_numpy()[0][j]
        y_b = y_b + a.to_numpy()[0][j]
    s = y_s/math.sqrt(y_s+y_b)
    if s > max:
        max = s
        index = i
print(max, index)

# %%
hist_ZH1 =  file[ 'wzp6_ee_nunuH_Hmumu_ecm240/missingEnergy2;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/missingEnergy2;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/missingEnergy2;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/missingEnergy2;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/missingEnergy2;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/missingEnergy2;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/missingEnergy2;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/missingEnergy2;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/missingEnergy2;1'].to_hist()
hist_ZZ1 = file['p8_ee_ZZ_ecm240/missingEnergy2;1'].to_hist()
#file[ 'wzp6_ee_nunuH_Hmumu_ecm240/missingEnergy;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1+hist_ZZ1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel("missing energy", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.vlines(72, 0, 10000, color = 'black', linestyles='dashed')
plt.xlim(0,111)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/cosThetaMiss;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/cosThetaMiss;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cosThetaMiss;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cosThetaMiss;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cosThetaMiss;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cosThetaMiss;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cosThetaMiss;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cosThetaMiss;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/cosThetaMiss;1'].to_hist() + file['p8_ee_ZZ_ecm240/cosThetaMiss;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel("cos theta", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
plt.xlim(-2,2)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/acoplanarity;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/acoplanarity;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/acoplanarity;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/acoplanarity;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/acoplanarity;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/acoplanarity;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/acoplanarity;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/acoplanarity;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/acoplanarity;1'].to_hist() + file['p8_ee_ZZ_ecm240/acoplanarity;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" acoplanarity ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.xlim(-2,2)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/acolinearity;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/acolinearity;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/acolinearity;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/acolinearity;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/acolinearity;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/acolinearity;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/acolinearity;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/acolinearity;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/acolinearity;1'].to_hist() + file['p8_ee_ZZ_ecm240/acolinearity;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" acolinearity ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.xlim(-2,2)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/leps_theta_final;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/leps_theta_final;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/leps_theta_final;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_theta_final;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_theta_final;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_theta_final;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_theta_final;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/leps_theta_final;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/leps_theta_final;1'].to_hist() + file['p8_ee_ZZ_ecm240/leps_theta_final;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" theta ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.xlim(-2,2)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/leps_phi_final;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/leps_phi_final;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/leps_phi_final;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_phi_final;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_phi_final;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_phi_final;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_phi_final;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/leps_phi_final;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/leps_phi_final;1'].to_hist() + file['p8_ee_ZZ_ecm240/leps_phi_final;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" phi ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.xlim(-2,2)

# %%
#'wzp6_ee_nunuH_Hmumu_ecm240/p_plus;1',
#'wzp6_ee_nunuH_Hmumu_ecm240/p_minus;1'
    
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/p_leading;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/p_leading;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/p_leading;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/p_leading;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/p_leading;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/p_leading;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/p_leading;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/p_leading;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/p_leading;1'].to_hist() + file['p8_ee_ZZ_ecm240/p_leading;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" leading-muon ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.xlim(-2,2)

# %%
#'wzp6_ee_nunuH_Hmumu_ecm240/p_plus;1',
#'wzp6_ee_nunuH_Hmumu_ecm240/p_minus;1'
    
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/p_subleading;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/p_subleading;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/p_subleading;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/p_subleading;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/p_subleading;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/p_subleading;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/p_subleading;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/p_subleading;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/p_subleading;1'].to_hist() + file['p8_ee_ZZ_ecm240/p_subleading;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" subleading-muon ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')

# %%
    
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist() + file['p8_ee_ZZ_ecm240/zll_leps_dR_incorrectPairs;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" DeltaR ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/zmumu_ll_m_final;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/zmumu_ll_m_final;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/zmumu_ll_m_final;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/zmumu_ll_m_final;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/zmumu_ll_m_final;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/zmumu_ll_m_final;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/zmumu_ll_m_final;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/zmumu_ll_m_final;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/zmumu_ll_m_final;1'].to_hist() + file['p8_ee_ZZ_ecm240/zmumu_ll_m_final;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" FINAL MASS NEW Z ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/zmumu_ll_recoil_m;1'].to_hist() + file['p8_ee_ZZ_ecm240/zmumu_ll_recoil_m;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" Recoil MASS NEW Z ", size=14)
plt.ylabel("events", size=14)
plt.legend(loc='upper right')
#plt.xlim(84, 118)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/zmumu_extra;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/zmumu_extra;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/zmumu_extra;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/zmumu_extra;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/zmumu_extra;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/zmumu_extra;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/zmumu_extra;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/zmumu_extra;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/zmumu_extra;1'].to_hist() + file['p8_ee_ZZ_ecm240/zmumu_extra;1'].to_hist()
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/zmumu_extra;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/zmumu_extra;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/zmumu_extra;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/zmumu_extra;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/zmumu_extra;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/zmumu_extra;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/zmumu_extra;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/zmumu_extra;1'].to_hist()
#       2 hist_WW1 = file['p8_ee_WW_ecm240/zmumu_extra;1'].to_hist() + file['p8_ee_ZZ_ecm240/zmumu_extra;1'].to_hist()
#
# File /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/uproot/reading.py:2091, in ReadOnlyDirectory.__getitem__(self, where)
#    2089     else:
#    2090         last = step
# ...

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" number of leptons ", size=14)
plt.ylabel("events", size=14)
plt.legend(loc='upper right')

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/final_leps;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/final_leps;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/final_leps;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/final_leps;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/final_leps;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/final_leps;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/final_leps;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/final_leps;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/final_leps;1'].to_hist() + file['p8_ee_ZZ_ecm240/final_leps;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" number of leptons ", size=14)
plt.ylabel("events", size=14)
plt.yscale('log')
plt.legend(loc='upper right')

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/zmumu_ll_p;1'].to_hist() + file['p8_ee_ZZ_ecm240/zmumu_ll_p;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" momentum ", size=14)
plt.ylabel("events", size=14)
plt.legend(loc='upper right')

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/leps_all_p_cut0;1'].to_hist() 
hist_ZZ1 = file['p8_ee_ZZ_ecm240/leps_all_p_cut0;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
hep.histplot([ hist_ZH1, hist_WW1,hist_ZZ1], label=["ZH1", "ZZ1", "WW1"], histtype = 'fill', stack = True)
plt.xlabel(" momentum ", size=14)
plt.ylabel("events", size=14)
plt.legend(loc='upper right')
plt.xlim(0,125)
# Out:
# (0.0, 125.0)

# %%
plt.figure(figsize=(8,6))
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" number of leptons ", size=14)
plt.ylabel("events", size=14)
plt.yscale('log')
plt.legend(loc='upper right')

# %%
hist_ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()
hist_WW = file['p8_ee_WW_ecm240/leps_all_p_cut0;1'].to_hist() 
hist_ZZ = file['p8_ee_ZZ_ecm240/leps_all_p_cut0;1'].to_hist()
hey = [ hist_ZZ, hist_WW]

# %%
plt.figure(figsize=(8,7))
hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',],  stack = True)
hep.histplot(hist_ZH*10, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('$Momentum$ $[GeV]$')
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,125)
plt.legend(loc='upper right', fontsize = 7)
plt.vlines(25, 0, 1000, color = 'black', linestyles = 'dashed')
plt.xticks([0, 25,40,60, 80, 100, 120])
plt.savefig("$Momentum$ $[GeV]$")

# %%
hist_ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/leps_all_no_cut0;1'].to_hist()
hist_WW = file['p8_ee_WW_ecm240/leps_all_no_cut0;1'].to_hist() 
hist_ZZ = file['p8_ee_ZZ_ecm240/leps_all_no_cut0;1'].to_hist()
hey = [ hist_ZZ, hist_WW]

# %%
plt.figure(figsize=(8,6))
hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'])
hep.histplot(hist_ZH*10, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('$Number $ $of$ $muons$', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,10)
plt.legend(loc='upper right', fontsize = 10)

plt.savefig("$Number $ $of$ $muons$")

# %%
file = uproot.recreate("combine/Hgaga.root")
file["sig"] = hist_ZH1
file["bkg"] = hist_WW2 + hist_ZZ1

# %%
hist_ZZ1 =  file['p8_ee_ZZ_ecm240/cutFlow_cut7;1'].to_hist()
hist_ZH1 =   + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()
hist_WW2 =  file['p8_ee_WW_ecm240/cutFlow_cut7;1'].to_hist()


ZZ = file['p8_ee_ZZ_ecm240/cutFlow_cut0;1'].to_hist()
accZZ = sum(hist_ZZ1.to_numpy()[0])/sum(ZZ.to_numpy()[0])
WW = file['p8_ee_WW_ecm240/cutFlow_cut0;1'].to_hist()
accWW = sum(hist_WW2.to_numpy()[0])/sum(WW.to_numpy()[0])
ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()
accZH = sum(hist_ZH1.to_numpy()[0])/sum(ZH.to_numpy()[0])
print(accZZ, accWW, accZH)
# Out:
# 0.0024272243557589635 0.028407799999999997 0.8001645173487208

# %%
hist_ZZ1 =  file['p8_ee_ZZ_ecm240/cutFlow_cut1;1'].to_hist()
hist_ZH1 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()
hist_WW2 =  file['p8_ee_WW_ecm240/cutFlow_cut1;1'].to_hist()


ZZ = file['p8_ee_ZZ_ecm240/cutFlow_cut0;1'].to_hist()
accZZ = sum(hist_ZZ1.to_numpy()[0])/sum(ZZ.to_numpy()[0])
WW = file['p8_ee_WW_ecm240/cutFlow_cut0;1'].to_hist()
accWW = sum(hist_WW2.to_numpy()[0])/sum(WW.to_numpy()[0])
ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()
accZH = sum(hist_ZH1.to_numpy()[0])/sum(ZH.to_numpy()[0])
print(accZH, accZZ, accWW)
# Out:
# 0.999058135962931 0.1047758 0.9746636

# %%
hist_ZZ1 =  file['p8_ee_ZZ_ecm240/cutFlow_cut6;1'].to_hist()
hist_ZH1 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()
hist_WW2 =  file['p8_ee_WW_ecm240/cutFlow_cut6;1'].to_hist()


ZZ = file['p8_ee_ZZ_ecm240/cutFlow_cut0;1'].to_hist()
accZZ = sum(hist_ZZ1.to_numpy()[0])/sum(ZZ.to_numpy()[0])
WW = file['p8_ee_WW_ecm240/cutFlow_cut0;1'].to_hist()
accWW = sum(hist_WW2.to_numpy()[0])/sum(WW.to_numpy()[0])
ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()
accZH = sum(hist_ZH1.to_numpy()[0])/sum(ZH.to_numpy()[0])
print(accZH, accZZ, accWW)
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 hist_ZZ1 =  file['p8_ee_ZZ_ecm240/cutFlow_cut6;1'].to_hist()
#       2 hist_ZH1 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()
#       3 hist_WW2 =  file['p8_ee_WW_ecm240/cutFlow_cut6;1'].to_hist()
#
# File /work/submit/simdenis/miniforge3/envs/cern/lib/python3.9/site-packages/uproot/writing/writable.py:968, in WritableDirectory.__getitem__(self, where)
# ...

# %%
hist_ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/hll_no_cut2;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/hll_no_cut2;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/hll_no_cut2;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/hll_no_cut2;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/hll_no_cut2;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/hll_no_cut2;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/hll_no_cut2;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/hll_no_cut2;1'].to_hist()
hist_WW = file['p8_ee_WW_ecm240/hll_no_cut2;1'].to_hist() 
hist_ZZ = file['p8_ee_ZZ_ecm240/hll_no_cut2;1'].to_hist()
hey = [ hist_ZZ, hist_WW]

# %%
plt.figure(figsize=(8,6))
hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_ZH*10, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('$Number $ $of$ $muons$', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,10)
plt.legend(loc='upper right', fontsize = 10)

plt.savefig("$Number $ $of$ $muons$")

# %%
hist_ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/leps_all_p_cut0;1'].to_hist()
hist_WW = file['p8_ee_WW_ecm240/leps_all_p_cut0;1'].to_hist() 
hist_ZZ = file['p8_ee_ZZ_ecm240/leps_all_p_cut0;1'].to_hist()
hey = [ hist_ZZ, hist_WW]

# %%
plt.figure(figsize=(8,6))
hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_ZH*10, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('momentum', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
#plt.xlim(0,10)
plt.legend(loc='upper right', fontsize = 10)

# %%
hist_ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/zmumu_ll_recoil_m;1'].to_hist()
hist_WW = file['p8_ee_WW_ecm240/zmumu_ll_recoil_m;1'].to_hist() 
hist_ZZ = file['p8_ee_ZZ_ecm240/zmumu_ll_recoil_m;1'].to_hist()
hey = [ hist_ZZ, hist_WW]

# %%
plt.figure(figsize=(8,6))
hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_ZH*10, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('recoil mass, 4 muons ', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
#plt.xlim(0,10)
plt.legend(loc='upper right', fontsize = 10)
# Out:
# /tmp/ipykernel_3045310/8346379.py:6: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale("log")

# %%
hist_ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/zmumu_ll_p;1'].to_hist()
hist_WW = file['p8_ee_WW_ecm240/zmumu_ll_p;1'].to_hist() 
hist_ZZ = file['p8_ee_ZZ_ecm240/zmumu_ll_p;1'].to_hist()
hey = [ hist_ZZ, hist_WW]

# %%
plt.figure(figsize=(8,6))
hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_ZH*10, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('momentum, 4 muons ', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
#plt.xlim(0,10)
plt.legend(loc='upper right', fontsize = 10)
# Out:
# /tmp/ipykernel_3045310/3534911182.py:6: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   plt.yscale("log")

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/rec_and_mass;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/rec_and_mass;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/rec_and_mass;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/rec_and_mass;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/rec_and_mass;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/rec_and_mass;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/rec_and_mass;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/rec_and_mass;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/rec_and_mass;1'].to_hist() + file['p8_ee_ZZ_ecm240/rec_and_mass;1'].to_hist()

# %%
sig = hist_ZH1
print(sig)

bkg = hist_WW1
fig, ax = plt.subplots(1, 2)
fig.set_figheight(5)
fig.set_figwidth(10)
hep.hist2dplot(sig, cmap = 'Blues', norm = 'linear', ax = ax[1])
hep.hist2dplot(bkg, cmap = 'Reds', norm = 'linear', ax = ax[0])
#ax[1].set_xlim(90, 100)
#ax[1].set_ylim(124, 126)
ax[0].set_xlabel('Rec mass')
ax[0].set_ylabel('Inv mass')
ax[0].set_title('Background proc')
#ax[1].set_xlim(50, 120)
#ax[1].set_ylim(70, 140)
ax[1].set_xlabel('Rec mass')
ax[1].set_ylabel('Inv mass')
ax[1].set_title('Signal proc')
fig.tight_layout()
sig2 = sig.to_numpy()[0]
bkg2 = bkg.to_numpy()[0]
print(sig2[1000][1250])
# Out:
# Hist(
#   Regular(3000, 0, 300, name='xaxis'),
#   Regular(3000, 0, 300, name='yaxis'),
#   storage=Weight()) # Sum: WeightedSum(value=-nan, variance=0.0382748) (WeightedSum(value=-nan, variance=0.0382748) with flow)
# 0.07929226519034911

# %%
significance = sig2

# %%
for a in range (3000):
    for b in range(3000):
        if(math.sqrt(sig2[a][b]+bkg2[a][b])):
            significance[a][b] = (sig2[a][b])/math.sqrt(sig2[a][b]+bkg2[a][b])
        #print(significance[a][b])

# %%
hep.hist2dplot(significance, cmap = 'Reds')
plt.xlim(850,1050)
plt.ylim(1240,1260)
plt.title("Significance")
# Out:
# ...
# Text(0.5, 1.0, 'Significance')

# %%
new_s = sig.to_numpy()
print(len(new_s[0]))
for a in range (300):
    for b in range(300):
        new_s[0][a][b] = 0
        for i in range(10):
            for j in range(10):
                new_s[0][a][b] = significance[a*10+i][b*10+j] + new_s[0][a][b]
                
                
print(new_s[0][125][91])
print(len(new_s[2]))
# Out:
# 3000
# 0.0034183984843620167
# 3001

# %%
#hey = np.histogram(new_s, bins = 3000, range = (0,300))


hep.hist2dplot(new_s, cmap = 'Reds')

#plt.xlim(80,105)
#plt.ylim(124,126)
# Out:
# ...
# ColormeshArtists(pcolormesh=<matplotlib.collections.QuadMesh object at 0x7f3715ed3250>, cbar=<matplotlib.colorbar.Colorbar object at 0x7f3715eebc40>, text=[])

# %%
num_bins_new = 3000


bin_width = 300 / num_bins_new


histogram_new = [0] * num_bins_new
