# %%
import ROOT
import argparse
import math
import hist as hs
import numpy as np
from hist import Hist
import random
import matplotlib.pyplot as plt
import uproot 
import mplhep as hep

file=uproot.open("tmp/output_mumu.root")
#file.keys()

# %%
hist_ZH1 =  file[ 'wzp6_ee_nunuH_Hmumu_ecm240/missingEnergy_f;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/missingEnergy_f;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/missingEnergy_f;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/missingEnergy_f;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/missingEnergy_f;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/missingEnergy_f;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/missingEnergy_f;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/missingEnergy_f;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/missingEnergy_f;1'].to_hist()
hist_ZZ1 = file['p8_ee_ZZ_ecm240/missingEnergy_f;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1+hist_ZZ1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel("missing energy", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.vlines(72, 0, 10000, color = 'black', linestyles='dashed')
plt.xlim(0,111)
# Out:
# (0.0, 111.0)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/cosThetaMiss_f;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/cosThetaMiss_f;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cosThetaMiss_f;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cosThetaMiss_f;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cosThetaMiss_f;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cosThetaMiss_f;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cosThetaMiss_f;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cosThetaMiss_f;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/cosThetaMiss_f;1'].to_hist() + file['p8_ee_ZZ_ecm240/cosThetaMiss_f;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel("cos theta", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
plt.xlim(-2,2)
# Out:
# (-2.0, 2.0)

# %%
hist_ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/momentum_f;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/momentum_f;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/momentum_f;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/momentum_f;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/momentum_f;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/momentum_f;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/momentum_f;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/momentum_f;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/momentum_f;1'].to_hist() + file['p8_ee_ZZ_ecm240/momentum_f;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH, label="ZH1", histtype = 'fill')
plt.xlabel("momentum", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
plt.xlim(25,50)
# Out:
# (25.0, 50.0)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/acoplanarity_f;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/acoplanarity_f;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/acoplanarity_f;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/acoplanarity_f;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/acoplanarity_f;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/acoplanarity_f;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/acoplanarity_f;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/acoplanarity_f;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/acoplanarity_f;1'].to_hist() + file['p8_ee_ZZ_ecm240/acoplanarity_f;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" acoplanarity ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.xlim(-2,2)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/acolinearity_f;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/acolinearity_f;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/acolinearity_f;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/acolinearity_f;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/acolinearity_f;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/acolinearity_f;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/acolinearity_f;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/acolinearity_f;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/acolinearity_f;1'].to_hist() + file['p8_ee_ZZ_ecm240/acolinearity_f;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" acolinearity ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.xlim(-2,2)

# %%
hist_ZH1 =  file['wzp6_ee_nunuH_Hmumu_ecm240/Delta_R;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/Delta_R;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/Delta_R;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/Delta_R;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/Delta_R;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/Delta_R;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/Delta_R;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/Delta_R;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/Delta_R;1'].to_hist() + file['p8_ee_ZZ_ecm240/Delta_R;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel(" DeltaR ", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')

# %%
hist_ZH1 =  file[ 'wzp6_ee_nunuH_Hmumu_ecm240/missingEnergy_nunu;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/missingEnergy_nunu;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/missingEnergy_nunu;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/missingEnergy_nunu;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/missingEnergy_nunu;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/missingEnergy_nunu;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/missingEnergy_nunu;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/missingEnergy_nunu;1'].to_hist()
hist_WW1 = file['p8_ee_WW_ecm240/missingEnergy_nunu;1'].to_hist()
hist_ZZ1 = file['p8_ee_ZZ_ecm240/missingEnergy_nunu;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
a = hist_WW1+hist_ZZ1
hep.histplot(a, label="bkg", histtype = 'fill')
#hep.histplot(hist_WW1, label="WW1", histtype = 'fill')
#hep.histplot(hist_ZZ1, label="ZZ1", histtype = 'fill')
hep.histplot(hist_ZH1, label="ZH1", histtype = 'fill')
plt.xlabel("missing energy", size=14)
plt.ylabel("events", size=14)
plt.yscale("log")
plt.legend(loc='upper right')
#plt.vlines(72, 0, 10000, color = 'black', linestyles='dashed')
plt.xlim(0,111)
# Out:
# (0.0, 111.0)

# %%
hist_ZH_m = file['wzp6_ee_nunuH_Hmumu_ecm240/mass_nunu;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/mass_nunu;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/mass_nunu;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/mass_nunu;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/mass_nunu;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/mass_nunu;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/mass_nunu;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/mass_nunu;1'].to_hist()


hist_ZZ_m = file['p8_ee_ZZ_ecm240/mass_nunu;1'].to_hist()

hist_WW_m = file['p8_ee_WW_ecm240/mass_nunu;1'].to_hist()

# %%
plt.figure(figsize=(8,8))
#hep.histplot(hey, label = [ "ZZ", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',], edgecolor = ['black', 'black'], linewidth=[1,1], stack = True)
hep.histplot(hist_ZZ_m, label="ZZ", histtype = 'fill', color = 'skyblue')
hep.histplot(hist_WW_m, label="WW", histtype = 'fill', color = 'deeppink')
hep.histplot(hist_ZH_m, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')


plt.ylabel("$events$", size=14)
plt.yscale("log")
plt.xlabel('mass_nunu', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(60,140)
plt.legend(loc='upper left', fontsize = 10)
#plt.ylim(0,100000)

# %%
hist_ZH_m = file['wzp6_ee_nunuH_Hmumu_ecm240/mass_mumu;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/mass_mumu;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/mass_mumu;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/mass_mumu;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/mass_mumu;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/mass_mumu;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/mass_mumu;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/mass_mumu;1'].to_hist()


hist_ZZ_m = file['p8_ee_ZZ_ecm240/mass_mumu;1'].to_hist()

hist_WW_m = file['p8_ee_WW_ecm240/mass_mumu;1'].to_hist()

# %%
plt.figure(figsize=(8,8))
#hep.histplot(hey, label = [ "ZZ", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',], edgecolor = ['black', 'black'], linewidth=[1,1], stack = True)
hep.histplot(hist_ZZ_m, label="ZZ", histtype = 'fill', color = 'skyblue')
hep.histplot(hist_WW_m, label="WW", histtype = 'fill', color = 'deeppink')
hep.histplot(hist_ZH_m, label="ZH($\mu^{+}\mu^{-}) - signal$", histtype = 'fill', color = 'orange')


plt.ylabel("$events$", size=14)
plt.yscale("log")
plt.xlabel('Invariant mass [GeV]', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,120)
plt.legend(loc='upper left', fontsize = 10)
#plt.ylim(0,100000)

# %%
hist_ZH_m = file['wzp6_ee_nunuH_Hmumu_ecm240/mass_ee;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/mass_ee;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/mass_ee;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/mass_ee;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/mass_ee;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/mass_ee;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/mass_ee;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/mass_ee;1'].to_hist()


hist_ZZ_m = file['p8_ee_ZZ_ecm240/mass_ee;1'].to_hist()

hist_WW_m = file['p8_ee_WW_ecm240/mass_ee;1'].to_hist()

# %%
plt.figure(figsize=(8,8))
#hep.histplot(hey, label = [ "ZZ", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',], edgecolor = ['black', 'black'], linewidth=[1,1], stack = True)
hep.histplot(hist_ZZ_m, label="ZZ", histtype = 'fill', color = 'skyblue')
hep.histplot(hist_WW_m, label="WW", histtype = 'fill', color = 'deeppink')
hep.histplot(hist_ZH_m, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')


plt.ylabel("$events$", size=14)
plt.yscale("log")
plt.xlabel('Invariant mass [GeV] ', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,120)
plt.legend(loc='upper left', fontsize = 10)
#plt.ylim(0,100000)

# %%
hist_ZH_m = file['wzp6_ee_nunuH_Hmumu_ecm240/nu_muons;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/nu_muons;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/nu_muons;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/nu_muons;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/nu_muons;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/nu_muons;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/nu_muons;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/nu_muons;1'].to_hist()


hist_ZZ_m = file['p8_ee_ZZ_ecm240/nu_muons;1'].to_hist()

hist_WW_m = file['p8_ee_WW_ecm240/nu_muons;1'].to_hist()

# %%
plt.figure(figsize=(8,8))
#hep.histplot(hey, label = [ "ZZ", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',], edgecolor = ['black', 'black'], linewidth=[1,1], stack = True)
hep.histplot(hist_ZZ_m, label="ZZ", histtype = 'fill', color = 'skyblue')
hep.histplot(hist_WW_m, label="WW", histtype = 'fill', color = 'deeppink')
hep.histplot(hist_ZH_m, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')


plt.ylabel("$events$", size=14)
plt.yscale("log")
plt.xlabel('number of muons', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
#plt.xlim(0,120)
plt.legend(loc='upper right', fontsize = 10)
#plt.ylim(0,100000)
