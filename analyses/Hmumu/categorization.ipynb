# %%
import ROOT
import argparse
import math
import hist as hs
import numpy as np
from hist import Hist
import random
import matplotlib.pyplot as plt
import uproot 
import mplhep as hep

file=uproot.open("tmp/output_mumu.root")
#file.keys()

# %%
ahist_ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/jet_e1;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/jet_e1;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/jet_e1;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/jet_e1;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/jet_e1;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/jet_e1;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/jet_e1;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/jet_e1;1'].to_hist()

ahist_ZH2 = file['wzp6_ee_nunuH_Hmumu_ecm240/jet_e2;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/jet_e2;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/jet_e2;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/jet_e2;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/jet_e2;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/jet_e2;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/jet_e2;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/jet_e2;1'].to_hist()

hist_ZH = file['wzp6_ee_qqH_Hmumu_ecm240/jet_e1;1'].to_hist()
hist_ZH2 = file['wzp6_ee_qqH_Hmumu_ecm240/jet_e2;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
#hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_ZH)

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('jets energy', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
#plt.xlim(0,130)
plt.legend(loc='upper right', fontsize = 10)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(8,6))
#hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_ZH, label="jet1",  )
hep.histplot(hist_ZH2, label="jet2")

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('jets energy', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
#plt.xlim(0,10)
plt.legend(loc='upper right', fontsize = 10)

# %%
hist_ZH1 = file['wzp6_ee_nunuH_Hmumu_ecm240/final_mass;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/final_mass;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/final_mass;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/final_mass;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/final_mass;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/final_mass;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/final_mass;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/final_mass;1'].to_hist()
hist_ZH = file['wzp6_ee_qqH_Hmumu_ecm240/final_mass;1']
hist_WW = file['p8_ee_WW_ecm240/final_mass;1'].to_hist() 
hist_ZZ = file['p8_ee_ZZ_ecm240/final_mass;1'].to_hist()
hey = [ hist_ZZ, hist_WW]

# %%
plt.figure(figsize=(8,6))
#hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_ZH, color = 'skyblue')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('invariant mass[GeV]', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,120)
plt.legend(loc='upper right', fontsize = 10)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(8,6))
#hep.histplot(hey, label = [ "$ZZ$", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink'], stack = True)
hep.histplot(hist_ZH1, color = 'deeppink')

plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlabel('mass', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
#plt.xlim(0,100)
plt.legend(loc='upper right', fontsize = 10)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
hist_ZH = file['wzp6_ee_nunuH_Hmumu_ecm240/jet_e1;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/jet_e1;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/jet_e1;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/jet_e1;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/jet_e1;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/jet_e1;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/jet_e1;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/jet_e1;1'].to_hist()

hist_ZH2 = file['wzp6_ee_nunuH_Hmumu_ecm240/jet_e2;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/jet_e2;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/jet_e2;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/jet_e2;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/jet_e2;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/jet_e2;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/jet_e2;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/jet_e2;1'].to_hist()

hist_ZZ = file['p8_ee_ZZ_ecm240/jet_e1;1'].to_hist()

hist_ZZ2 = file['p8_ee_ZZ_ecm240/jet_e2;1'].to_hist()

hist_WW = file['p8_ee_WW_ecm240/jet_e1;1'].to_hist()

hist_WW2 = file['p8_ee_WW_ecm240/jet_e2;1'].to_hist()

# %%
plt.figure(figsize=(8,6))
#hep.histplot(hey, label = [ "ZZ", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',], edgecolor = ['black', 'black'], linewidth=[1,1], stack = True)
hep.histplot(hist_ZZ, label="ZZ", histtype = 'fill', color = 'skyblue', edgecolor= 'black', linewidth = 1)
hep.histplot(hist_WW, label="WW", histtype = 'fill', color = 'deeppink', edgecolor= 'black', linewidth = 1)
hep.histplot(hist_ZH, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange', edgecolor= 'black', linewidth = 1)


plt.ylabel("$events$", size=14)
plt.yscale("log")
plt.xlabel('energy jet 1', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,130)
plt.legend(loc='upper right', fontsize = 10)
plt.ylim(0,100000)
# Out:
# /tmp/ipykernel_3577627/1547642348.py:16: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,100000)
# (9.94084011143586e-05, 100000)

# %%
plt.figure(figsize=(8,8))
#hep.histplot(hey, label = [ "ZZ", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',], edgecolor = ['black', 'black'], linewidth=[1,1], stack = True)
hep.histplot(hist_ZZ2, label="ZZ", histtype = 'fill', color = 'skyblue', edgecolor= 'black', linewidth = 1)
hep.histplot(hist_WW2, label="WW", histtype = 'fill', color = 'deeppink', edgecolor= 'black', linewidth = 1)
hep.histplot(hist_ZH2, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange', edgecolor= 'black', linewidth = 1)


plt.ylabel("$events$", size=14)
plt.yscale("log")
plt.xlabel('energy jet 2', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,70)
plt.legend(loc='upper right', fontsize = 10)
plt.ylim(0,100000)
# Out:
# /tmp/ipykernel_3577627/1854093611.py:16: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,100000)
# (0.00040436496685911376, 100000)

# %%
hist_ZH_m = file['wzp6_ee_nunuH_Hmumu_ecm240/final_mass;1'].to_hist()+ file['wzp6_ee_eeH_Hmumu_ecm240/final_mass;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/final_mass;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/final_mass;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/final_mass;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/final_mass;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/final_mass;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/final_mass;1'].to_hist()


hist_ZZ_m = file['p8_ee_ZZ_ecm240/final_mass;1'].to_hist()

hist_WW_m = file['p8_ee_WW_ecm240/final_mass;1'].to_hist()

# %%
plt.figure(figsize=(8,8))
#hep.histplot(hey, label = [ "ZZ", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',], edgecolor = ['black', 'black'], linewidth=[1,1], stack = True)
hep.histplot(hist_ZZ_m, label="ZZ", histtype = 'fill', color = 'skyblue')
hep.histplot(hist_WW_m, label="WW", histtype = 'fill', color = 'deeppink')
hep.histplot(hist_ZH_m, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange')


plt.ylabel("$events$", size=14)
plt.yscale("log")
plt.xlabel('mass', fontsize =14)
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 7.2$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,120)
plt.legend(loc='upper right', fontsize = 10)
#plt.ylim(0,100000)

# %%
hist_ZH = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut1;1'].to_hist() + file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut2;1'].to_hist()+file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut0;1'].to_hist()+ file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut3;1'].to_hist() + file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut4;1'].to_hist()+ file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut5;1'].to_hist()+ file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut6;1'].to_hist()+ file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut7;1'].to_hist()+file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut8;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut8;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut8;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut8;1'].to_hist()+file[ 'wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut8;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut8;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut8;1'].to_hist()  + file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut8;1'].to_hist()+file[ 'wzp6_ee_nunuH_Hmumu_ecm240/cutFlow_cut9;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/cutFlow_cut9;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/cutFlow_cut9;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/cutFlow_cut9;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/cutFlow_cut9;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/cutFlow_cut9;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/cutFlow_cut9;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/cutFlow_cut9;1'].to_hist() 
   
hist_ZZ = file['p8_ee_ZZ_ecm240/cutFlow_cut0;1'].to_hist() + file['p8_ee_ZZ_ecm240/cutFlow_cut1;1'].to_hist()+file['p8_ee_ZZ_ecm240/cutFlow_cut2;1'].to_hist() + file['p8_ee_ZZ_ecm240/cutFlow_cut3;1'].to_hist() + file['p8_ee_ZZ_ecm240/cutFlow_cut4;1'].to_hist()+file['p8_ee_ZZ_ecm240/cutFlow_cut5;1'].to_hist()+file['p8_ee_ZZ_ecm240/cutFlow_cut6;1'].to_hist()+file['p8_ee_ZZ_ecm240/cutFlow_cut7;1'].to_hist()+file['p8_ee_ZZ_ecm240/cutFlow_cut8;1'].to_hist()+ file['p8_ee_ZZ_ecm240/cutFlow_cut9;1'].to_hist() 
hist_WW = file['p8_ee_WW_ecm240/cutFlow_cut1;1'].to_hist() + file['p8_ee_WW_ecm240/cutFlow_cut0;1'].to_hist()+file['p8_ee_WW_ecm240/cutFlow_cut2;1'].to_hist() + file['p8_ee_WW_ecm240/cutFlow_cut3;1'].to_hist() +file['p8_ee_WW_ecm240/cutFlow_cut4;1'].to_hist()+file['p8_ee_WW_ecm240/cutFlow_cut5;1'].to_hist()+file['p8_ee_WW_ecm240/cutFlow_cut6;1'].to_hist()+file['p8_ee_WW_ecm240/cutFlow_cut7;1'].to_hist()+ file['p8_ee_WW_ecm240/cutFlow_cut8;1'].to_hist()+file['p8_ee_WW_ecm240/cutFlow_cut9;1'].to_hist()


hey = [ hist_ZZ, hist_WW]
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[27], line 1
# ...

# %%
plt.figure(figsize=(16,6))
hep.histplot(hey, label = [ "ZZ", "$W^{-}W^{+}$"] , histtype = 'fill', color = [ 'skyblue', 'deeppink',], edgecolor = ['black', 'black'], linewidth=[1,1], stack = True)
hep.histplot(hist_ZZ, label="ZZ", histtype = 'fill', color = 'skyblue', edgecolor= 'black', linewidth = 1)
hep.histplot(hist_ZH, label="ZH($\mu^{+}\mu^{-})*10 - signal$", histtype = 'fill', color = 'orange', edgecolor= 'black', linewidth = 1)
#hep.histplot(hist_WW, label="$W^{-}W^{+}$", histtype = 'fill', color='deeppink', edgecolor= 'black', linewidth = 1)

plt.xticks([0.5,1.5,2.5,3.5,4.5,5.5,6.5,7.5, 8.5, 9.5], ["$All$ $events$", "$ \geq 1\mu^{\pm} $", "$ \geq 2\mu^{\pm}$", "$Opposite$ $charge$", "$ 87 < m_{rec} < 115$", "$ 34 < p_{\mu^{+}\mu^{-}} < 72 $ ", "$MissingEnergy < 111 $", 'JUST QQ', 'enegry2', 'energy 1']) # "$102 < m_{\mu^{+}\mu^{-}}$ < 127 "])
plt.ylabel("$Events$", size=12)
plt.yscale("log")
plt.xlabel('')
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 10$ $ab^{-1} $", fontsize = 14)
#hep.cms.lumitext(text = "$ 100 ab^{-1}$")
plt.xlim(0,10)
plt.legend(loc='upper right')

# %%
hist_ZZ1 =  file['p8_ee_ZZ_ecm240/mass_f;1'].to_hist()
hist_ZH1 = file[ 'wzp6_ee_nunuH_Hmumu_ecm240/mass_f;1'].to_hist() + file['wzp6_ee_eeH_Hmumu_ecm240/mass_f;1'].to_hist()+file['wzp6_ee_ccH_Hmumu_ecm240/mass_f;1'].to_hist()  + file['wzp6_ee_tautauH_Hmumu_ecm240/mass_f;1'].to_hist()+file['wzp6_ee_bbH_Hmumu_ecm240/mass_f;1'].to_hist() + file['wzp6_ee_qqH_Hmumu_ecm240/mass_f;1'].to_hist()+file['wzp6_ee_ssH_Hmumu_ecm240/mass_f;1'].to_hist() +file['wzp6_ee_mumuH_Hmumu_ecm240/mass_f;1'].to_hist()
hist_WW2 =  file['p8_ee_WW_ecm240/mass_f;1'].to_hist()

# %%
plt.figure(figsize=(9,8))
#hep.histplot([ hist_ZZ1, hist_WW2], label = [  "$ZZ$", "$W^{-}W^{+}$"] ,  color = [ 'skyblue', 'deeppink'] , histtype = 'fill', stack = True)
hep.histplot(hist_ZH1, label = "ZH($\mu^{+}\mu^{-}) - signal$", color = 'red')

#"ZH($\mu^{+}\mu^{-}) - signal$", "$ZZ$",
plt.xlabel("$Invariant$ $mass$ $[GeV]$", size=14)
plt.ylabel("$Events$", size=14)
plt.yscale("log")
plt.xlim(120,127)
plt.annotate("Category: $qq$", (121.2, 10), weight = 1000, horizontalalignment = 'right')
hep.cms.text(text = "Simulation", exp = "FCC-ee", fontsize = 14)
hep.cms.lumitext(text = "$\sqrt{s} = 240$ $GeV, 10$ $ab^{-1} $", fontsize = 14)
plt.legend(loc='upper left')
